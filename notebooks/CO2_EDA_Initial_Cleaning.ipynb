# %% [markdown]
# # Task
# Perform an exploratory data analysis (EDA) on the "Co2 emmision dataset fetched by API.csv" file to understand its characteristics, identify missing values, explore data statistics and potential inconsistencies, visualize key feature distributions, and summarize data quality issues ('cons') to inform subsequent machine learning model development.

# %% [markdown]
# ## Load Dataset
#
# ### Subtask:
# Load the provided CSV file, 'Co2 emmision dataset fetched by API.csv', into a pandas DataFrame for initial exploration.

# %%
import pandas as pd
df = pd.read_csv('Co2 emmision dataset fetched by API.csv')
print(df.head())
# Out:
#    period sectorId                              sector-name fuelId  \
# 0    2022       CC      Commercial carbon dioxide emissions     CO
# 1    2022       CC      Commercial carbon dioxide emissions     NG
# 2    2022       CC      Commercial carbon dioxide emissions     PE
# 3    2022       CC      Commercial carbon dioxide emissions     TO
# 4    2022       EC  Electric Power carbon dioxide emissions     CO
#
#      fuel-name stateId state-name     value                 value-units
# 0         Coal      AK     Alaska  0.700224  million metric tons of CO2
# 1  Natural Gas      AK     Alaska  0.834685  million metric tons of CO2
# 2    Petroleum      AK     Alaska  0.679345  million metric tons of CO2
# 3    All Fuels      AK     Alaska  2.214254  million metric tons of CO2
# 4         Coal      AK     Alaska  1.083045  million metric tons of CO2

# %% [markdown]
# ## Initial Data Overview
#
# ### Subtask:
# Display basic information about the dataset, including its shape, column names, data types, and a few sample rows.

# %%
print(f"DataFrame shape: {df.shape}")
print("\nDataFrame Info:")
df.info()
# Out:
# DataFrame shape: (66144, 9)
#
# DataFrame Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 66144 entries, 0 to 66143
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   period       66144 non-null  int64
#  1   sectorId     66144 non-null  object
#  2   sector-name  66144 non-null  object
#  3   fuelId       66144 non-null  object
#  4   fuel-name    66144 non-null  object
#  5   stateId      66144 non-null  object
#  6   state-name   66144 non-null  object
#  7   value        66144 non-null  float64
#  8   value-units  66144 non-null  object
# dtypes: float64(1), int64(1), object(7)
# memory usage: 4.5+ MB

# %%
print("\nFirst 5 rows of the DataFrame:")
print(df.head())
# Out:
# First 5 rows of the DataFrame:
#    period sectorId                              sector-name fuelId  \
# 0    2022       CC      Commercial carbon dioxide emissions     CO
# 1    2022       CC      Commercial carbon dioxide emissions     NG
# 2    2022       CC      Commercial carbon dioxide emissions     PE
# 3    2022       CC      Commercial carbon dioxide emissions     TO
# 4    2022       EC  Electric Power carbon dioxide emissions     CO
#
#      fuel-name stateId state-name     value                 value-units
# 0         Coal      AK     Alaska  0.700224  million metric tons of CO2
# 1  Natural Gas      AK     Alaska  0.834685  million metric tons of CO2
# 2    Petroleum      AK     Alaska  0.679345  million metric tons of CO2
# 3    All Fuels      AK     Alaska  2.214254  million metric tons of CO2
# 4         Coal      AK     Alaska  1.083045  million metric tons of CO2

# %% [markdown]
# ## Identify Missing Values
#
# ### Subtask:
# Check for and quantify any missing values in each column of the dataset.
#
# ### Reasoning:
# To explicitly confirm the absence of missing values, I will use `df.isnull().sum()` to display the count of null values for each column, as instructed.

# %% [markdown]
# **Reasoning**:
# As instructed, I will use `df.isnull().sum()` to confirm that there are no missing values in the dataset, providing a quantitative count for each column.

# %% [markdown]
# ## Explore Data Statistics and Potential Inconsistencies
#
# ### Subtask:
# Generate descriptive statistics for numerical columns and examine unique values for categorical columns to identify potential outliers, inconsistencies, or data entry errors that could be 'cons' in the data.

# %% [markdown]
# **Reasoning**:
# To understand the distribution and potential outliers in numerical features, I will display the descriptive statistics of the DataFrame.

# %% [markdown]
# **Reasoning**:
# To complete the subtask, I will now identify categorical columns (object type) and print their unique values and counts, which will help in identifying potential inconsistencies or variations, also known as 'cons' in the data.

# %%
print("\nUnique values and their counts for categorical columns:")
for column in df.select_dtypes(include='object').columns:
    print(f"\nColumn: {column}")
    print(df[column].value_counts())
# Out:
# Unique values and their counts for categorical columns:
#
# Column: sectorId
# sectorId
# CC    11024
# EC    11024
# IC    11024
# RC    11024
# TC    11024
# TT    11024
# Name: count, dtype: int64
#
# Column: sector-name
# sector-name
# Commercial carbon dioxide emissions                11024
# Electric Power carbon dioxide emissions            11024
# Industrial carbon dioxide emissions                11024
# Residential carbon dioxide emissions               11024
# Transportation carbon dioxide emissions            11024
# Total carbon dioxide emissions from all sectors    11024
# Name: count, dtype: int64
#
# Column: fuelId
# fuelId
# CO    16536
# NG    16536
# PE    16536
# TO    16536
# Name: count, dtype: int64
#
# Column: fuel-name
# fuel-name
# Coal           16536
# Natural Gas    16536
# Petroleum      16536
# All Fuels      16536
# Name: count, dtype: int64
#
# Column: stateId
# stateId
# AK    1272
# AL    1272
# ND    1272
# NE    1272
# NH    1272
# NJ    1272
# ...

# %% [markdown]
# ## Visualize Key Feature Distributions
#
# ### Subtask:
# Create visualizations for relevant features to understand their distributions, relationships, and identify data quality issues or anomalies. Ensure all plots have appropriate legends and labels.

# %% [markdown]
# **Reasoning**:
# To begin visualizing the key feature distributions, I will import the necessary plotting libraries, `matplotlib.pyplot` and `seaborn`, as instructed.

# %% [markdown]
# # Model Persistence and Prediction

# %% [markdown]
# **Reasoning**:
# Now that the DataFrame is sorted by relevant columns, I will calculate the 1-year lagged value and the 3-year rolling mean for the `value_log_transformed` column within each group, and then fill any resulting NaN values with 0, as per the instructions. Finally, I will display the head of the DataFrame to show the new features.

# %% [markdown]
# ## Encode Categorical Features
#
# ### Subtask:
# Apply appropriate encoding techniques (e.g., one-hot encoding or label encoding) to the categorical columns ('sector-name' and 'fuel-name') to convert them into a numerical format that machine learning models can process effectively. Consider the implications of each encoding method on model performance.

# %% [markdown]
# **Reasoning**:
# To encode the categorical columns, I will first identify 'sector-name' and 'fuel-name' and then apply one-hot encoding using `pd.get_dummies()` to create new numerical features.

# %% [markdown]
# ## Prepare Data for Model Training
#
# ### Subtask:
# Review the processed dataset to ensure all features are in a suitable format for machine learning. This step will involve finalizing the feature set and preparing the data for splitting into training and testing sets.

# %% [markdown]
# **Reasoning**:
# To finalize the feature set and prepare the data for machine learning, I will define the target variable `y` and the feature matrix `X` by selecting and dropping specified columns, then split them into training and testing sets using `train_test_split`.

# %% [markdown]
# ## Final Task
#
# ### Subtask:
# Summarize the data preprocessing and feature engineering steps taken, and discuss how these preparations address the identified 'cons' and set the stage for machine learning model development.
